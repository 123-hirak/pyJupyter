calculated_vp_oil = df['Vp_Cal(oil)']

# Plot data
plt.scatter(measured_vp, calculated_vp_brine, label='Calculated Vp (Brine)',marker ='o',color = 'red',s=60)
plt.scatter(measured_vp, calculated_vp_air, label='Calculated Vp (Air)',marker ='*',color ='yellow')
plt.scatter(measured_vp, calculated_vp_oil, label='Calculated Vp (Oil)',marker ='*',color ='blue')
plt.xlabel('Measured Vp(km/s)')
plt.ylabel('Calculated Vp(km/s)')
plt.legend()

# Draw intercept line
fit = np.polyfit(measured_vp, calculated_vp_air, 1)
intercept = fit[1]
slope = fit[0]
x_range = np.linspace(min(measured_vp), max(measured_vp), 100)
y_range = slope * x_range + intercept
plt.plot(x_range, y_range, color='black')

plt.show()

# %%
import plotly as py
import plotly.graph_objs as go
# Extract Measured Vp and Calculated Vp for brine and air
measured_vs = df['Vs1(km/s)']
calculated_vs_brine = df['Vs_Cal(brine)']
calculated_vs_air = df['Vs_Cal(air)']
calculated_vs_oil = df['Vs_Cal(oil)']

# Plot data
plt.scatter(measured_vp, calculated_vp_brine, label='Calculated Vs (Brine)',marker ='o',color = 'red',s=60)
plt.scatter(measured_vp, calculated_vp_air, label='Calculated Vs (Air)',marker ='*',color ='yellow')
plt.scatter(measured_vp, calculated_vp_oil, label='Calculated Vs (Oil)',marker ='*',color ='blue')
plt.xlabel('Measured Vs(km/s)')
plt.ylabel('Calculated Vs(km/s)')
plt.legend()

# Draw intercept line
fit = np.polyfit(measured_vs, calculated_vs_brine, 1)
intercept = fit[1]
slope = fit[0]
x_range = np.linspace(min(measured_vp), max(measured_vp), 100)
y_range = slope * x_range + intercept
plt.plot(x_range, y_range, color='black')

plt.show()

# %%
import seaborn as sns
vp_diff = calculated_vp_brine - calculated_vp_air
sns.distplot(df['Vp(km/s)']-df['Vp_Cal(air)'])
plt.xlabel("Vp Diffrences(km/s)")
# Out:
# C:\Users\Hirak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Vp Diffrences(km/s)')

# %%
import seaborn as sns
vp_diff = calculated_vp_brine - calculated_vp_air
sns.distplot(df['Vp(km/s)']-df['Vp_Cal(brine)'])
plt.xlabel("Vp Diffrences(km/s)")
# Out:
# C:\Users\Hirak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Vp Diffrences(km/s)')

# %%
import seaborn as sns
vp_diff = calculated_vp_brine - calculated_vp_air
sns.distplot(df['Vp(km/s)']-df['Vp_Cal(oil)'])
plt.xlabel("Vp Diffrences(km/s)")
# Out:
# C:\Users\Hirak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Vp Diffrences(km/s)')

# %%
plt.figure(1, figsize=(10,6))
n = 0
for x in ['Vp(km/s)',  'Vp_Cal(air)',   'Vp_Cal(brine)',  'Vp_Cal(oil)']:
    n = n + 1
    plt.subplot(1, 4, n)
    plt.subplots_adjust(hspace = 1, wspace = .5)
    sns.distplot(df[x], bins=5)
    plt.title('Distribution Plot', loc='center')
#plt.savefig('Hirak.png',dpi=1500)
plt.show()
# Out:
# C:\Users\Hirak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hirak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hirak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hirak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df, vars = ['Vp(km/s)','Vp_Cal(air)', 'Vp_Cal(brine)','Vp_Cal(oil)'],hue='Visual inspection')
